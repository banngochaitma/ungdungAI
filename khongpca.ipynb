# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_train = pd.read_csv('data/train.csv')
data_test = pd.read_csv('data/test.csv')
features = ['id', 'cycle', 'setting1', 'setting2', 'setting3','s1','s2', 's3', 's4','s5', 's6',  's7', 's8', 's9','s10',  's11', 's12', 's13', 's14', 's15',  's16',
            's17', 's18', 's19',  's20', 's21','ttf','label_bnc']

data_train[features].describe()
# Out:
#                  id         cycle      setting1      setting2  setting3  \
# count  20631.000000  20631.000000  20631.000000  20631.000000   20631.0
# mean      51.506568    108.807862     -0.000009      0.000002     100.0
# std       29.227633     68.880990      0.002187      0.000293       0.0
# min        1.000000      1.000000     -0.008700     -0.000600     100.0
# 25%       26.000000     52.000000     -0.001500     -0.000200     100.0
# 50%       52.000000    104.000000      0.000000      0.000000     100.0
# 75%       77.000000    156.000000      0.001500      0.000300     100.0
# max      100.000000    362.000000      0.008700      0.000600     100.0
#
#              s1            s2            s3            s4            s5  ...  \
# count  20631.00  20631.000000  20631.000000  20631.000000  2.063100e+04  ...
# mean     518.67    642.680934   1590.523119   1408.933782  1.462000e+01  ...
# std        0.00      0.500053      6.131150      9.000605  1.776400e-15  ...
# ...

# %%
data_train[features].head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85  1406.22
#
#       s5  ...      s14     s15   s16  s17   s18    s19    s20      s21  ttf  \
# 0  14.62  ...  8138.62  8.4195  0.03  392  2388  100.0  39.06  23.4190  191
# 1  14.62  ...  8131.49  8.4318  0.03  392  2388  100.0  39.00  23.4236  190
# 2  14.62  ...  8133.23  8.4178  0.03  390  2388  100.0  38.95  23.3442  189
# 3  14.62  ...  8133.83  8.3682  0.03  392  2388  100.0  38.88  23.3739  188
# 4  14.62  ...  8133.80  8.4294  0.03  393  2388  100.0  38.90  23.4044  187
#
#    label_bnc
# 0          0
# 1          0
# ...

# %%
data_train[features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 28 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         20631 non-null  int64
#  1   cycle      20631 non-null  int64
#  2   setting1   20631 non-null  float64
#  3   setting2   20631 non-null  float64
#  4   setting3   20631 non-null  float64
#  5   s1         20631 non-null  float64
#  6   s2         20631 non-null  float64
#  7   s3         20631 non-null  float64
#  8   s4         20631 non-null  float64
#  9   s5         20631 non-null  float64
#  10  s6         20631 non-null  float64
#  11  s7         20631 non-null  float64
#  12  s8         20631 non-null  float64
#  13  s9         20631 non-null  float64
#  14  s10        20631 non-null  float64
#  15  s11        20631 non-null  float64
#  16  s12        20631 non-null  float64
#  17  s13        20631 non-null  float64
#  18  s14        20631 non-null  float64
# ...

# %%
data_train[features].shape
# Out:
# (20631, 28)

# %%
data_train[features].dtypes
# Out:
# id             int64
# cycle          int64
# setting1     float64
# setting2     float64
# setting3     float64
# s1           float64
# s2           float64
# s3           float64
# s4           float64
# s5           float64
# s6           float64
# s7           float64
# s8           float64
# s9           float64
# s10          float64
# s11          float64
# s12          float64
# s13          float64
# s14          float64
# s15          float64
# s16          float64
# s17            int64
# s18            int64
# s19          float64
# s20          float64
# s21          float64
# ttf            int64
# label_bnc      int64
# dtype: object

# %% [markdown]
# ## xử lí dữ liệu

# %%
# %matplotlib inline
sns.heatmap(data=data_train[features].isnull(), yticklabels=False, cbar =False, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
data = data_train[features]

# %%
sns.boxplot(data = data['s2'],orient="h")
# Out:
# <AxesSubplot:>

# %%
upper_lim = data['s3'].quantile(.999)
lower_lim = data['s3'].quantile(.001)
data = data[(data['s3'] < upper_lim) & (data['s3'] > lower_lim)]

# %%
upper_lim = data['s4'].quantile(.999)
lower_lim = data['s4'].quantile(.001)
data = data[(data['s4'] < upper_lim) & (data['s4'] > lower_lim)]

# %%
upper_lim = data['s7'].quantile(.999)
lower_lim = data['s7'].quantile(.001)
data = data[(data['s7'] < upper_lim) & (data['s7'] > lower_lim)]

# %%
upper_lim = data['s8'].quantile(.98)
lower_lim = data['s8'].quantile(.001)
data = data[(data['s8'] < upper_lim) & (data['s8'] > lower_lim)]

# %%
upper_lim = data['s9'].quantile(.98)

data = data[(data['s9'] < upper_lim) ]

# %%
upper_lim = data['s11'].quantile(.99)

data = data[(data['s11'] < upper_lim) ]

# %%
upper_lim = data['s12'].quantile(.99)
lower_lim = data['s12'].quantile(.01)
data = data[(data['s12'] < upper_lim) & (data['s12'] > lower_lim)]

# %%
upper_lim = data['s13'].quantile(.99)
lower_lim = data['s13'].quantile(.01)
data = data[(data['s13'] < upper_lim) & (data['s13'] > lower_lim)]

# %%
upper_lim = data['s20'].quantile(.99)
lower_lim = data['s20'].quantile(.01)
data = data[(data['s20'] < upper_lim) & (data['s20'] > lower_lim)]

# %%
upper_lim = data['s21'].quantile(.99)
lower_lim = data['s21'].quantile(.01)
data = data[(data['s21'] < upper_lim) & (data['s21'] > lower_lim)]

# %%
# we create a correlation matrix that measures the linear relationships between the variables.
correlation_matrix = data[features].corr().round(2)
# annot = True to print the values inside the square
plt.figure(figsize=(15,10))
sns.heatmap(data=correlation_matrix, annot=True, )
# Out:
# <AxesSubplot:>

# %%
col_names = ['s2', 's4', 's7',  's11', 's12',  's15',  's17',  's20', 's21']

# %%
# sample plot data
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.scatter(data.s2, data.ttf, c='orange')
plt.title('ttf vs s2')
plt.xlabel('s2')
plt.ylabel('ttf')

plt.subplot(1,2,2)
plt.scatter(data.s7, data.ttf, c='darkblue')
plt.title('ttf vs s7')
plt.xlabel('s7')
plt.ylabel('ttf')
# Out:
# Text(0, 0.5, 'ttf')

# %%
X_train =data[col_names]
y_train = data['ttf']
X_test = data_test[col_names]
y_test = data_test['ttf']

# %% [markdown]
# ## dự đoán linear regression

# %%
from sklearn.linear_model import LinearRegression
# model object
lrModel = LinearRegression()

# %%
# train model
lrModel.fit(X=X_train, y=y_train)
# Out:
# LinearRegression()

# %%
print('Model coefficients:', lrModel.coef_)
print('Model bias:', lrModel.intercept_)
# Out:
# Model coefficients: [  -9.96549932   -1.0598425     4.60599649  -42.51888833    5.87481616
#  -183.47325105   -4.2607591    33.47641419   68.79806753]
# Model bias: 4737.060961959952

# %%
prediction = lrModel.predict(X_test)
prediction
# Out:
# array([ 1.51634232e+02,  1.09423141e+02,  7.39291066e+01,  8.15730595e+01,
#         1.04840883e+02,  1.18149893e+02,  1.33407421e+02,  8.53910738e+01,
#         1.16571090e+02,  1.17251206e+02,  7.96491716e+01,  1.17580400e+02,
#         9.97037420e+01,  9.97790244e+01,  1.69441937e+02,  1.40045787e+02,
#         9.70127683e+01,  7.14178359e+01,  1.17496054e+02,  3.83989818e+00,
#         1.39352129e+02,  1.37148042e+02,  1.52551892e+02,  7.10608939e+01,
#         1.26864119e+02,  1.46407772e+02,  1.16786547e+02,  1.07274494e+02,
#         1.28548313e+02,  9.79614084e+01,  1.83092357e+01,  1.19346273e+02,
#         9.81514937e+01, -1.87312937e+01, -1.79802421e-01,  2.66156493e+01,
#         6.16423842e+01,  7.68198965e+01,  1.57121821e+02,  2.89413446e+01,
#         7.28276607e+01,  1.45208475e+01,  7.16113048e+01,  1.11276968e+02,
#         8.44664309e+01,  7.08343830e+01,  1.14546687e+02,  1.12897169e+02,
# ...

# %%
df2 = pd.DataFrame({'thực': y_test, 'dự đoán': prediction})
df2.head(5)
# Out:
#    thực     dự đoán
# 0   112  172.580645
# 1    98  141.906131
# 2    69   85.247385
# 3    82  102.141253
# 4    91  118.050135

# %%
# R^2 % của dự đoán
train_acc = lrModel.score(X=X_train, y=y_train)
test_acc = lrModel.score(X_test, y_test)
print("R^2 on train set:", round(train_acc*100,1), '%')
print("R^2 on test set:", round(test_acc*100,1), '%')
# Out:
# R^2 on train set: 57.9 %
# R^2 on test set: 43.2 %

# %%
from sklearn.metrics import mean_squared_error
print('MSE on train set:', mean_squared_error(y_train,lrModel.predict(X_train)))
print('MSE on test set:', mean_squared_error(y_test,lrModel.predict(X_test)))
print('RMSE on train set:', np.sqrt(mean_squared_error(y_train,lrModel.predict(X_train))/y_train.shape[0]))
print('RMSE on test set:', np.sqrt(mean_squared_error(y_test,lrModel.predict(X_test))/y_test.shape[0]))
# Out:
# MSE on train set: 1724.5475554548832
# MSE on test set: 981.3679797436826
# RMSE on train set: 0.3123352653665046
# RMSE on test set: 3.132679332047381

# %% [markdown]
# ## dự đoán Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor()
regr.fit(X_train, y_train)
y_pred = regr.predict(X_test)
y_pred
# Out:
# array([176.77, 163.2 ,  60.81,  76.11, 102.5 ,  87.79, 119.43,  69.04,
#        145.84, 112.27,  87.93,  98.69,  94.11, 152.34, 167.94, 105.94,
#         53.14,  61.37, 109.65,  25.1 ,  63.22, 167.2 , 139.57,  25.16,
#        146.25, 120.76,  98.1 ,  83.21,  98.22,  82.73,  25.49,  48.8 ,
#        135.82,  13.01,   7.72,  24.65,  48.74,  50.1 , 158.71,  30.57,
#         62.06,  19.64,  56.14, 140.52,  73.53,  45.53, 121.65, 125.29,
#         19.64, 118.31,  82.64,  30.4 ,  34.7 , 132.01, 112.79,  14.82,
#         85.45,  50.23, 147.04, 101.7 ,  45.86,  60.54,  54.96,  46.27,
#        156.03,  17.11, 149.82,  16.51, 149.19,  77.77, 135.91,  61.85,
#        135.78,  85.49, 130.  ,  14.33,  34.06, 170.3 ,  96.89,  85.19,
#         10.28,  12.4 , 130.32,  44.  , 168.05,  80.33, 151.67, 136.87,
#        106.32,  41.22,  34.61,  23.77,  51.27,  48.14, 125.3 , 143.87,
#         78.11,  82.49, 131.46,  21.31])

# %%
train_acc = regr.score(X=X_train, y=y_train)
test_acc = regr.score(X_test, y_test)
print("R^2 on train set:", round(train_acc*100,1), '%')
print("R^2 on test set:", round(test_acc*100,1), '%')
# Out:
# R^2 on train set: 95.1 %
# R^2 on test set: 60.5 %

# %%
df2 = pd.DataFrame({'thực': y_test, 'dự đoán': y_pred})
df2.head(5)
# Out:
#    thực  dự đoán
# 0   112   176.77
# 1    98   163.20
# 2    69    60.81
# 3    82    76.11
# 4    91   102.50
